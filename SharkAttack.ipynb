# %%
#Shark Attack

# %%
import pandas as pd
import numpy as np
#from IPython.display import display

# %%
attacks = pd.read_csv('attacks.csv', encoding='latin1')
pd.options.display.max_columns = None
#attacks.head(5)

# %%
attacks_br = attacks[attacks.Country.isin(['BRAZIL'])]

# %%
attacks_br = attacks_br.drop(['Case Number','Country','Injury','Time','Investigator or Source','pdf','href formula','href','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'], axis=1)

# %%
attacks_br.head(3)
# Out:
#                     Date    Year        Type        Area  \
# 6            03-Jun-2018  2018.0  Unprovoked  Pernambuco
# 27           15-Apr-2018  2018.0  Unprovoked  Pernambuco
# 31  Reported 10-Apr-2018  2018.0     Invalid     Alagoas
#
#                      Location  Activity                    Name Sex  Age  \
# 6       Piedade Beach, Recife  Swimming  Jose Ernesto da Silva     M  18
# 27                    Piedade  Swimming           Pablo de Melo    M  34
# 31  Praia de Sauaçuhy, Maceió   Fishing              Josias Paz    M  56
#
#    Fatal (Y/N)                         Species
# 6            Y                      Tiger shark
# 27         NaN                              NaN
# 31           N  Shark involvement not confirmed

# %%
attacks_br = attacks_br.fillna('Unknown')

# %%
attacks_br = attacks_br[attacks_br['Type'] != 'Invalid']

# %%
attacks_br = attacks_br[attacks_br['Type'] != 'Sea Disaster']

# %%
attacks_br
# Out:
#                       Date    Year        Type                 Area  \
# 6              03-Jun-2018  2018.0  Unprovoked           Pernambuco
# 27             15-Apr-2018  2018.0  Unprovoked           Pernambuco
# 51             12-Jan-2018  2018.0  Unprovoked  Fernando de Noronha
# 177            06-Feb-2017  2017.0    Provoked           Pernambuco
# 181            24-Jan-2017  2017.0  Unprovoked           Pernambuco
# ...                    ...     ...         ...                  ...
# 3070           28-Mar-1980  1980.0  Unprovoked       Rio de Janeiro
# 4569           10-Oct-1947  1947.0  Unprovoked           Pernambuco
# 4586              Feb-1947  1947.0  Unprovoked       Rio de Janeiro
# 5777  Reported 28-Apr-1884  1884.0  Unprovoked              Unknown
# 6101              Dec-1826  1826.0  Unprovoked              Paraiba
#
#                               Location  \
# 6                Piedade Beach, Recife
# 27                             Piedade
# 51                     Conceicao Beach
# 177    Fernando de Noronha Marine Park
# 181                 Boa Viagem, Recife
# ...                                ...
# 3070  Copacabana Beach, Rio de Janiero
# 4569                           Piedade
# 4586                        Copacabana
# 5777                             Bahia
# 6101                           Paraiba
#
#                                      Activity                            Name  \
# 6                                    Swimming          Jose Ernesto da Silva
# 27                                   Swimming                   Pablo de Melo
# 51                                    Surfing        Ricardo Ferrari Bulhoes
# 177               Grabbing shark for a selfie                          female
# 181                                  Swimming                  Arthur Andrade
# ...                                       ...                             ...
# 3070                                 Swimming                            J.M.
# 4569                                Swimming       Father Serafin de Oliveira
# 4586                                  Bathing                         Unknown
# 5777  Fell overboard from the steamship Chala                            male
# 6101                                  Unknown  a seaman from the ship Beverly
#
#          Sex       Age Fatal (Y/N)         Species
# 6           M       18           Y      Tiger shark
# 27          M       34     Unknown          Unknown
# 51          M       20           N      small shark
# 177         F  Unknown           N  Lemon shark pup
# 181         M       21           N          Unknown
# ...       ...      ...         ...              ...
# 3070        M  Unknown           N        2 m shark
# 4569        M       25           Y          Unknown
# 4586  Unknown  Unknown           Y          Unknown
# 5777        M  Unknown           Y          Unknown
# 6101        M  Unknown           N          Unknown
#
# [97 rows x 11 columns]

# %%
myset = set(attacks_br['Area'])
keys_list = list(myset)
keys_list.sort()
values_list = ['BA','SC','PE','MA','PB','PE','RS','RN','RJ','SC','Unknown']
zip_iterator = zip(keys_list, values_list)

a_dictionary = dict(zip_iterator)

print(a_dictionary)
# Out:
# {'Bahia': 'BA', 'Balneário Camboriú': 'SC', 'Fernando de Noronha': 'PE', 'Maranhão': 'MA', 'Paraiba': 'PB', 'Pernambuco': 'PE', 'Rio Grande Do Sul': 'RS', 'Rio Grande de Norte': 'RN', 'Rio de Janeiro': 'RJ', 'Santa Catarina State': 'SC', 'Unknown': 'Unknown'}

# %%
attacks_br['State'] = attacks_br['Area'].map(a_dictionary)

# %%
#pd.options.display.max_rows = None
attacks_br.head(3)
# Out:
#            Date    Year        Type                 Area  \
# 6   03-Jun-2018  2018.0  Unprovoked           Pernambuco
# 27  15-Apr-2018  2018.0  Unprovoked           Pernambuco
# 51  12-Jan-2018  2018.0  Unprovoked  Fernando de Noronha
#
#                  Location  Activity                      Name Sex  Age  \
# 6   Piedade Beach, Recife  Swimming    Jose Ernesto da Silva     M  18
# 27                Piedade  Swimming             Pablo de Melo    M  34
# 51        Conceicao Beach   Surfing  Ricardo Ferrari Bulhoes     M  20
#
#    Fatal (Y/N)     Species  State
# 6            Y  Tiger shark    PE
# 27     Unknown      Unknown    PE
# 51           N  small shark    PE

# %%
attacks_br.loc[attacks_br['State'] == 'Unknown']
# Out:
#                       Date    Year        Type     Area  \
# 543            09-Jun-2014  2014.0  Unprovoked  Unknown
# 1434           03-Sep-2006  2006.0  Unprovoked  Unknown
# 5777  Reported 28-Apr-1884  1884.0  Unprovoked  Unknown
#
#                                 Location  \
# 543   500 km off the coast of Pernambuco
# 1434                             Unknown
# 5777                               Bahia
#
#                                      Activity                    Name Sex   \
# 543                                   Fishing                 Sunarko    M
# 1434                                  Unknown  Darlan dos Santos Luz     M
# 5777  Fell overboard from the steamship Chala                    male    M
#
#           Age Fatal (Y/N) Species     State
# 543        43           N  Unknown  Unknown
# 1434       20           Y  Unknown  Unknown
# 5777  Unknown           Y  Unknown  Unknown

# %%
attacks_br.loc[attacks_br['Location'].str.contains('Pernambuco'), 'State'] = 'PE'

# %%
attacks_br.head(3)
# Out:
#            Date    Year        Type                 Area  \
# 6   03-Jun-2018  2018.0  Unprovoked           Pernambuco
# 27  15-Apr-2018  2018.0  Unprovoked           Pernambuco
# 51  12-Jan-2018  2018.0  Unprovoked  Fernando de Noronha
#
#                  Location  Activity                      Name Sex  Age  \
# 6   Piedade Beach, Recife  Swimming    Jose Ernesto da Silva     M  18
# 27                Piedade  Swimming             Pablo de Melo    M  34
# 51        Conceicao Beach   Surfing  Ricardo Ferrari Bulhoes     M  20
#
#    Fatal (Y/N)     Species  State
# 6            Y  Tiger shark    PE
# 27     Unknown      Unknown    PE
# 51           N  small shark    PE

# %%
attacks_br.loc[attacks_br['Location'].str.contains('Bahia'), 'State'] = 'BA'

# %%
attacks_br.head(3)
# Out:
#            Date    Year        Type                 Area  \
# 6   03-Jun-2018  2018.0  Unprovoked           Pernambuco
# 27  15-Apr-2018  2018.0  Unprovoked           Pernambuco
# 51  12-Jan-2018  2018.0  Unprovoked  Fernando de Noronha
#
#                  Location  Activity                      Name Sex  Age  \
# 6   Piedade Beach, Recife  Swimming    Jose Ernesto da Silva     M  18
# 27                Piedade  Swimming             Pablo de Melo    M  34
# 51        Conceicao Beach   Surfing  Ricardo Ferrari Bulhoes     M  20
#
#    Fatal (Y/N)     Species  State
# 6            Y  Tiger shark    PE
# 27     Unknown      Unknown    PE
# 51           N  small shark    PE

# %%
attacks_br = attacks_br[attacks_br['State'] != 'Unknown']

#attacks_br.groupby(by='Year').count()
attacks_br = attacks_br[attacks_br['Year'] >= 1980]

# %%
attacks_br = attacks_br.drop('Area',axis=1)

# %%
attacks_br
# Out:
#              Date    Year        Type                          Location  \
# 6     03-Jun-2018  2018.0  Unprovoked             Piedade Beach, Recife
# 27    15-Apr-2018  2018.0  Unprovoked                           Piedade
# 51    12-Jan-2018  2018.0  Unprovoked                   Conceicao Beach
# 177   06-Feb-2017  2017.0    Provoked   Fernando de Noronha Marine Park
# 181   24-Jan-2017  2017.0  Unprovoked                Boa Viagem, Recife
# ...           ...     ...         ...                               ...
# 2601  24-Apr-1991  1991.0    Provoked      Praia de Pau Amarelo, Recife
# 3038     Mar-1981  1981.0  Unprovoked                         Cabo Frio
# 3043     Feb-1981  1981.0  Unprovoked                         Cabo Frio
# 3053  11-Nov-1980  1980.0  Unprovoked                           Piedade
# 3070  28-Mar-1980  1980.0  Unprovoked  Copacabana Beach, Rio de Janiero
#
#                          Activity                      Name     Sex       Age  \
# 6                        Swimming    Jose Ernesto da Silva         M       18
# 27                       Swimming             Pablo de Melo        M       34
# 51                        Surfing  Ricardo Ferrari Bulhoes         M       20
# 177   Grabbing shark for a selfie                    female        F  Unknown
# 181                      Swimming            Arthur Andrade        M       21
# ...                           ...                       ...      ...      ...
# 2601                      Fishing                      L.F.  Unknown  Unknown
# 3038                       Diving                   Unknown  Unknown  Unknown
# 3043                 Spearfishing                   Unknown  Unknown  Unknown
# 3053                     Swimming      Ibson Gomes  Vieira         M       16
# 3070                     Swimming                      J.M.        M  Unknown
#
#      Fatal (Y/N)             Species  State
# 6              Y          Tiger shark    PE
# 27       Unknown              Unknown    PE
# 51             N          small shark    PE
# 177            N      Lemon shark pup    PE
# 181            N              Unknown    PE
# ...          ...                  ...   ...
# 2601           N  170-kg, 2.8 m shark    PE
# 3038     UNKNOWN          White shark    RJ
# 3043           N              Unknown    RJ
# 3053           Y              Unknown    PE
# 3070           N            2 m shark    RJ
#
# [92 rows x 11 columns]

# %%
attacks_br.loc[attacks_br['Name'] == 'male', 'Name'] = 'Unidentified'

# %%
attacks_br.loc[attacks_br['Name'] == 'female', 'Name'] = 'Unidentified'

# %%
attacks_br.loc[attacks_br['Name'] == 'Unknown', 'Name'] = 'Unidentified'

# %%
attacks_br
# Out:
#              Date    Year        Type                          Location  \
# 6     03-Jun-2018  2018.0  Unprovoked             Piedade Beach, Recife
# 27    15-Apr-2018  2018.0  Unprovoked                           Piedade
# 51    12-Jan-2018  2018.0  Unprovoked                   Conceicao Beach
# 177   06-Feb-2017  2017.0    Provoked   Fernando de Noronha Marine Park
# 181   24-Jan-2017  2017.0  Unprovoked                Boa Viagem, Recife
# ...           ...     ...         ...                               ...
# 2601  24-Apr-1991  1991.0    Provoked      Praia de Pau Amarelo, Recife
# 3038     Mar-1981  1981.0  Unprovoked                         Cabo Frio
# 3043     Feb-1981  1981.0  Unprovoked                         Cabo Frio
# 3053  11-Nov-1980  1980.0  Unprovoked                           Piedade
# 3070  28-Mar-1980  1980.0  Unprovoked  Copacabana Beach, Rio de Janiero
#
#                          Activity                      Name     Sex       Age  \
# 6                        Swimming    Jose Ernesto da Silva         M       18
# 27                       Swimming             Pablo de Melo        M       34
# 51                        Surfing  Ricardo Ferrari Bulhoes         M       20
# 177   Grabbing shark for a selfie              Unidentified        F  Unknown
# 181                      Swimming            Arthur Andrade        M       21
# ...                           ...                       ...      ...      ...
# 2601                      Fishing                      L.F.  Unknown  Unknown
# 3038                       Diving              Unidentified  Unknown  Unknown
# 3043                 Spearfishing              Unidentified  Unknown  Unknown
# 3053                     Swimming      Ibson Gomes  Vieira         M       16
# 3070                     Swimming                      J.M.        M  Unknown
#
#      Fatal (Y/N)             Species  State
# 6              Y          Tiger shark    PE
# 27       Unknown              Unknown    PE
# 51             N          small shark    PE
# 177            N      Lemon shark pup    PE
# 181            N              Unknown    PE
# ...          ...                  ...   ...
# 2601           N  170-kg, 2.8 m shark    PE
# 3038     UNKNOWN          White shark    RJ
# 3043           N              Unknown    RJ
# 3053           Y              Unknown    PE
# 3070           N            2 m shark    RJ
#
# [92 rows x 11 columns]

# %%
#cols = [8,9]
#attacks_br = attacks_br.drop(attacks_br.columns[cols], axis=1)

# %%
attacks_br.head(3)
# Out:
#            Date    Year        Type               Location  Activity  \
# 6   03-Jun-2018  2018.0  Unprovoked  Piedade Beach, Recife  Swimming
# 27  15-Apr-2018  2018.0  Unprovoked                Piedade  Swimming
# 51  12-Jan-2018  2018.0  Unprovoked        Conceicao Beach   Surfing
#
#                         Name Sex  Age Fatal (Y/N)     Species  State
# 6     Jose Ernesto da Silva     M  18           Y  Tiger shark    PE
# 27             Pablo de Melo    M  34     Unknown      Unknown    PE
# 51  Ricardo Ferrari Bulhoes     M  20           N  small shark    PE

# %%
attacks_br.groupby(attacks_br.columns[10]).count()
# Out:
#        Date  Year  Type  Location  Activity  Name  Sex   Age  Fatal (Y/N)  \
# State
# BA        2     2     2         2         2     2     2    2            2
# MA        4     4     4         4         4     4     4    4            4
# PE       72    72    72        72        72    72    72   72           72
# RJ        9     9     9         9         9     9     9    9            9
# RN        2     2     2         2         2     2     2    2            2
# RS        1     1     1         1         1     1     1    1            1
# SC        2     2     2         2         2     2     2    2            2
#
#        Species
# State
# BA            2
# MA            4
# PE           72
# RJ            9
# RN            2
# RS            1
# SC            2

# %%
attacks_br.groupby(attacks_br.columns[4]).count()
# Out:
#                                                     Date  Year  Type  \
# Activity
# Bathing                                                2     2     2
# Batin                                                  1     1     1
# Body boarding                                          4     4     4
# Boogie boarding                                        1     1     1
# Diving                                                 1     1     1
# Fishing                                                2     2     2
# Grabbing shark for a selfie                            1     1     1
# Killing  sharks                                        1     1     1
# Removing fish from a trap                              1     1     1
# Scientific research (Dr. Sonny Gruber's student)       1     1     1
# Scuba diving                                           1     1     1
# Spearfishing                                           1     1     1
# Spearfishing, but swimming at surface                  1     1     1
# Surfing                                               35    35    35
# Swimming                                              29    29    29
# Swimming                                               2     2     2
# Swimming, attempting to rescue a girl  believed...     1     1     1
# Unknown                                                5     5     5
# Wading                                                 1     1     1
# Windsurfing                                            1     1     1
#
#                                                     Location  Name  Sex   Age  \
# Activity
# Bathing                                                    2     2     2    2
# Batin                                                      1     1     1    1
# Body boarding                                              4     4     4    4
# Boogie boarding                                            1     1     1    1
# Diving                                                     1     1     1    1
# Fishing                                                    2     2     2    2
# Grabbing shark for a selfie                                1     1     1    1
# Killing  sharks                                            1     1     1    1
# Removing fish from a trap                                  1     1     1    1
# Scientific research (Dr. Sonny Gruber's student)           1     1     1    1
# Scuba diving                                               1     1     1    1
# Spearfishing                                               1     1     1    1
# Spearfishing, but swimming at surface                      1     1     1    1
# Surfing                                                   35    35    35   35
# Swimming                                                  29    29    29   29
# Swimming                                                   2     2     2    2
# Swimming, attempting to rescue a girl  believed...         1     1     1    1
# Unknown                                                    5     5     5    5
# Wading                                                     1     1     1    1
# Windsurfing                                                1     1     1    1
#
#                                                     Fatal (Y/N)  Species   \
# Activity
# Bathing                                                       2         2
# Batin                                                         1         1
# Body boarding                                                 4         4
# Boogie boarding                                               1         1
# Diving                                                        1         1
# Fishing                                                       2         2
# Grabbing shark for a selfie                                   1         1
# Killing  sharks                                               1         1
# Removing fish from a trap                                     1         1
# Scientific research (Dr. Sonny Gruber's student)              1         1
# Scuba diving                                                  1         1
# Spearfishing                                                  1         1
# Spearfishing, but swimming at surface                         1         1
# Surfing                                                      35        35
# Swimming                                                     29        29
# Swimming                                                      2         2
# Swimming, attempting to rescue a girl  believed...            1         1
# Unknown                                                       5         5
# Wading                                                        1         1
# Windsurfing                                                   1         1
#
#                                                     State
# Activity
# Bathing                                                 2
# Batin                                                   1
# Body boarding                                           4
# Boogie boarding                                         1
# Diving                                                  1
# Fishing                                                 2
# Grabbing shark for a selfie                             1
# Killing  sharks                                         1
# Removing fish from a trap                               1
# Scientific research (Dr. Sonny Gruber's student)        1
# Scuba diving                                            1
# Spearfishing                                            1
# Spearfishing, but swimming at surface                   1
# Surfing                                                35
# Swimming                                               29
# Swimming                                                2
# Swimming, attempting to rescue a girl  believed...      1
# Unknown                                                 5
# Wading                                                  1
# Windsurfing                                             1

# %%
#from IPython.display import display
#pd.options.display.max_rows = None
attacks_br.loc[attacks_br['Activity'].str.contains('Swim'), 'Act'] = 'SBW'

# %%
attacks_br.loc[attacks_br['Activity'].str.contains('Bat'), 'Act'] = 'SBW'
#from IPython.display import display
#pd.options.display.max_rows = None

# %%
attacks_br.loc[attacks_br['Activity'].str.contains('Wading'), 'Act'] = 'SBW'

# %%
#from IPython.display import display
#pd.options.display.max_rows = None
attacks_br.loc[attacks_br['Activity'].str.contains('iving'), 'Act'] = 'Diving'

# %%
attacks_br.loc[attacks_br['Activity'].str.contains('urfing'), 'Act'] = 'Surfing'

# %%
attacks_br.loc[attacks_br['Activity'].str.contains('boarding'), 'Act'] = 'Surfing'

# %%
attacks_br.loc[attacks_br['Activity'].str.contains('ish'), 'Act'] = 'Fishing'

# %%
attacks_br.loc[attacks_br['Activity'].str.contains('research'), 'Act'] = 'Scientific Research'

# %%
attacks_br.loc[attacks_br['Act'].isna(), 'Act'] = 'Others'

# %%
attacks_br = attacks_br.drop(attacks_br.columns[4], axis=1)

# %%
attacks_br.rename(columns={'Act':'Activity'}, inplace=True)

# %%
attacks_br = attacks_br.drop(attacks_br.columns[8], axis=1)

# %%
attacks_br.head(3)
# Out:
#            Date    Year        Type               Location  \
# 6   03-Jun-2018  2018.0  Unprovoked  Piedade Beach, Recife
# 27  15-Apr-2018  2018.0  Unprovoked                Piedade
# 51  12-Jan-2018  2018.0  Unprovoked        Conceicao Beach
#
#                         Name Sex  Age Fatal (Y/N) State Activity
# 6     Jose Ernesto da Silva     M  18           Y    PE      SBW
# 27             Pablo de Melo    M  34     Unknown    PE      SBW
# 51  Ricardo Ferrari Bulhoes     M  20           N    PE  Surfing

# %%
attacks_br = attacks_br.set_axis(['Date','Year','Type','Location','Name','Sex','Age','Fatal','State','Activity'], axis=1, inplace=False)

# %%
attacks_br.head(3)
# Out:
#            Date    Year        Type               Location  \
# 6   03-Jun-2018  2018.0  Unprovoked  Piedade Beach, Recife
# 27  15-Apr-2018  2018.0  Unprovoked                Piedade
# 51  12-Jan-2018  2018.0  Unprovoked        Conceicao Beach
#
#                         Name Sex Age    Fatal State Activity
# 6     Jose Ernesto da Silva    M  18        Y    PE      SBW
# 27             Pablo de Melo   M  34  Unknown    PE      SBW
# 51  Ricardo Ferrari Bulhoes    M  20        N    PE  Surfing

# %%
attacks_br = attacks_br[['Date','Year','Type','Fatal','Activity','Location','State','Name','Sex','Age']]

# %%
attacks_br.loc[attacks_br['Fatal'] == 'UNKNOWN', 'Fatal'] = 'Unknown'

# %%
attacks_br
# Out:
#              Date    Year        Type    Fatal Activity  \
# 6     03-Jun-2018  2018.0  Unprovoked        Y      SBW
# 27    15-Apr-2018  2018.0  Unprovoked  Unknown      SBW
# 51    12-Jan-2018  2018.0  Unprovoked        N  Surfing
# 177   06-Feb-2017  2017.0    Provoked        N   Others
# 181   24-Jan-2017  2017.0  Unprovoked        N      SBW
# ...           ...     ...         ...      ...      ...
# 2601  24-Apr-1991  1991.0    Provoked        N  Fishing
# 3038     Mar-1981  1981.0  Unprovoked  Unknown   Diving
# 3043     Feb-1981  1981.0  Unprovoked        N  Fishing
# 3053  11-Nov-1980  1980.0  Unprovoked        Y      SBW
# 3070  28-Mar-1980  1980.0  Unprovoked        N      SBW
#
#                               Location State                      Name  \
# 6                Piedade Beach, Recife    PE    Jose Ernesto da Silva
# 27                             Piedade    PE             Pablo de Melo
# 51                     Conceicao Beach    PE  Ricardo Ferrari Bulhoes
# 177    Fernando de Noronha Marine Park    PE              Unidentified
# 181                 Boa Viagem, Recife    PE            Arthur Andrade
# ...                                ...   ...                       ...
# 2601      Praia de Pau Amarelo, Recife    PE                      L.F.
# 3038                         Cabo Frio    RJ              Unidentified
# 3043                         Cabo Frio    RJ              Unidentified
# 3053                           Piedade    PE      Ibson Gomes  Vieira
# 3070  Copacabana Beach, Rio de Janiero    RJ                      J.M.
#
#           Sex      Age
# 6           M       18
# 27          M       34
# 51          M       20
# 177         F  Unknown
# 181         M       21
# ...       ...      ...
# 2601  Unknown  Unknown
# 3038  Unknown  Unknown
# 3043  Unknown  Unknown
# 3053        M       16
# 3070        M  Unknown
#
# [92 rows x 10 columns]

# %%
attacks_br.groupby(by=['Year']).agg(Brazil = ('State', 'count'))
# Out:
#         Brazil
# Year
# 1980.0       2
# 1981.0       2
# 1991.0       1
# 1992.0       6
# 1993.0       3
# 1994.0      10
# 1995.0       4
# 1996.0       4
# 1997.0       5
# 1998.0       4
# 1999.0       4
# 2001.0       2
# 2002.0       7
# 2003.0       5
# 2004.0       7
# 2005.0       1
# 2006.0       4
# 2007.0       1
# 2008.0       3
# 2009.0       2
# 2010.0       1
# 2011.0       2
# 2012.0       1
# 2013.0       2
# 2014.0       1
# 2015.0       1
# 2016.0       2
# 2017.0       2
# 2018.0       3

# %%
attacks_by_state = pd.crosstab(attacks_br['Year'],attacks_br['State'])
# Out:
# State   BA  MA  PE  RJ  RN  RS  SC
# Year
# 1980.0   0   0   1   1   0   0   0
# 1981.0   0   0   0   2   0   0   0
# 1991.0   0   0   1   0   0   0   0
# 1992.0   0   3   3   0   0   0   0
# 1993.0   0   0   3   0   0   0   0
# 1994.0   0   0  10   0   0   0   0
# 1995.0   0   1   3   0   0   0   0
# 1996.0   0   0   4   0   0   0   0
# 1997.0   0   0   3   2   0   0   0
# 1998.0   0   0   4   0   0   0   0
# 1999.0   0   0   2   1   1   0   0
# 2001.0   0   0   1   0   1   0   0
# 2002.0   0   0   7   0   0   0   0
# 2003.0   0   0   2   3   0   0   0
# 2004.0   0   0   7   0   0   0   0
# 2005.0   1   0   0   0   0   0   0
# 2006.0   0   0   4   0   0   0   0
# 2007.0   0   0   1   0   0   0   0
# 2008.0   1   0   2   0   0   0   0
# 2009.0   0   0   2   0   0   0   0
# 2010.0   0   0   0   0   0   1   0
# 2011.0   0   0   2   0   0   0   0
# 2012.0   0   0   1   0   0   0   0
# 2013.0   0   0   2   0   0   0   0
# 2014.0   0   0   1   0   0   0   0
# 2015.0   0   0   1   0   0   0   0
# 2016.0   0   0   0   0   0   0   2
# 2017.0   0   0   2   0   0   0   0
# 2018.0   0   0   3   0   0   0   0
