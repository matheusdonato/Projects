# %%
#Shark Attack

# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
attacks = pd.read_csv('attacks.csv', encoding='latin1')
pd.options.display.max_columns = None
#attacks.head(5)

# %%
attacks_br = attacks[attacks.Country.isin(['BRAZIL'])]

# %%
#attacks_br.head(3)

# %%
attacks_br = attacks_br.drop(['Country','pdf','href formula','href','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'], axis=1)

# %%
attacks_br.head(3)
# Out:
#      Case Number                  Date    Year        Type        Area  \
# 6   2018.06.03.a           03-Jun-2018  2018.0  Unprovoked  Pernambuco
# 27  2018.04.15.c           15-Apr-2018  2018.0  Unprovoked  Pernambuco
# 31  2018.04.10.R  Reported 10-Apr-2018  2018.0     Invalid     Alagoas
#
#                      Location  Activity                    Name Sex  Age  \
# 6       Piedade Beach, Recife  Swimming  Jose Ernesto da Silva     M  18
# 27                    Piedade  Swimming           Pablo de Melo    M  34
# 31  Praia de Sauaçuhy, Maceió   Fishing              Josias Paz    M  56
#
#                                                Injury Fatal (Y/N)  \
# 6                                               FATAL           Y
# 27  Multiple severe injuries to arms and leg, leg ...         NaN
# 31  Injury to ankle from marine animal trapped in ...           N
#
#               Time                         Species   \
# 6   Late afternoon                      Tiger shark
# ...

# %%
attacks_br.drop(['Case Number','Type','Injury','Investigator or Source'], axis=1)
# Out:
#                       Date    Year                  Area  \
# 6              03-Jun-2018  2018.0            Pernambuco
# 27             15-Apr-2018  2018.0            Pernambuco
# 31    Reported 10-Apr-2018  2018.0               Alagoas
# 44             11-Feb-2018  2018.0  Boi Island, Victoria
# 51             12-Jan-2018  2018.0   Fernando de Noronha
# ...                    ...     ...                   ...
# 5122           25-Oct-1927  1927.0          Porto Seguro
# 5746           20-Jan-1887  1887.0               Alagoas
# 5777  Reported 28-Apr-1884  1884.0                   NaN
# 5848           02-Feb-1878  1878.0                   NaN
# 6101              Dec-1826  1826.0               Paraiba
#
#                           Location  \
# 6            Piedade Beach, Recife
# 27                         Piedade
# 31       Praia de Sauaçuhy, Maceió
# 44                  Espirito Santo
# 51                 Conceicao Beach
# ...                            ...
# ...

# %%
import re
attacks_br.loc[attacks_br['Area'].isna(), 'Area'] = 'Unknown'
attacks_br.loc[attacks_br['Location'].isna(), 'Location'] = 'Unknown'
attacks_br.head(3)
# Out:
#      Case Number                  Date    Year        Type        Area  \
# 6   2018.06.03.a           03-Jun-2018  2018.0  Unprovoked  Pernambuco
# 27  2018.04.15.c           15-Apr-2018  2018.0  Unprovoked  Pernambuco
# 31  2018.04.10.R  Reported 10-Apr-2018  2018.0     Invalid     Alagoas
#
#                      Location  Activity                    Name Sex  Age  \
# 6       Piedade Beach, Recife  Swimming  Jose Ernesto da Silva     M  18
# 27                    Piedade  Swimming           Pablo de Melo    M  34
# 31  Praia de Sauaçuhy, Maceió   Fishing              Josias Paz    M  56
#
#                                                Injury Fatal (Y/N)  \
# 6                                               FATAL           Y
# 27  Multiple severe injuries to arms and leg, leg ...         NaN
# 31  Injury to ankle from marine animal trapped in ...           N
#
#               Time                         Species   \
# 6   Late afternoon                      Tiger shark
# ...

# %%
#attacks_br.loc[attacks_br['Type'] == 'Invalid']

# %%
attacks_br = attacks_br[attacks_br.Type != 'Invalid']
attacks_br = attacks_br[attacks_br.Type != 'Sea Disaster']
attacks_br.groupby(by='Type').count()
# Out:
#             Case Number  Date  Year  Area  Location  Activity  Name  Sex   \
# Type
# Provoked              5     5     5     5         5         4     5     4
# Unprovoked           92    92    92    92        92        86    89    81
#
#             Age  Injury  Fatal (Y/N)  Time  Species   Investigator or Source  \
# Type
# Provoked      1       5            5     2         2                       5
# Unprovoked   54      90           91    36        26                      92
#
#             Area + Location
# Type
# Provoked                  5
# Unprovoked               88

# %%
attacks_br.drop(['Case Number','Injury'
# Out:
#        Case Number                  Date    Year        Type  \
# 6     2018.06.03.a           03-Jun-2018  2018.0  Unprovoked
# 27    2018.04.15.c           15-Apr-2018  2018.0  Unprovoked
# 51      2018.01.12           12-Jan-2018  2018.0  Unprovoked
# 177   2017.02.06.b           06-Feb-2017  2017.0    Provoked
# 181     2017.01.24           24-Jan-2017  2017.0  Unprovoked
# ...            ...                   ...     ...         ...
# 3070    1980.03.28           28-Mar-1980  1980.0  Unprovoked
# 4569    1947.10.10           10-Oct-1947  1947.0  Unprovoked
# 4586    1947.02.00              Feb-1947  1947.0  Unprovoked
# 5777  1884.04.38.R  Reported 28-Apr-1884  1884.0  Unprovoked
# 6101    1826.12.00              Dec-1826  1826.0  Unprovoked
#
#                      Area                          Location  \
# 6              Pernambuco             Piedade Beach, Recife
# 27             Pernambuco                           Piedade
# ...
